# %%
import matplotlib.pyplot as plt
import numpy as np
import wave1D.functional as functional
import wave1D.signal_processing as signal_processing

% matplotlib inline

# %% [markdown]
# # Frequency synthesis of transient signal

# %%
T = 10.0
N = 1503
Dt = T / N
x = np.linspace(0., T, N)
u = functional.ricker(x - 2.0, 2.0)
plt.plot(x, u)
plt.show()

# %%
uf, f = signal_processing.frequency_synthesis(u, T, Dt)
plt.plot(freqs, np.abs(np.fft.rfft(u)))
plt.xlim([0, 10])
# Out:
# (0, 10)
